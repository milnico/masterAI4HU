# %% [markdown]
# <a href="https://colab.research.google.com/github/milnico/masterAI4HU/blob/main/Lezione5_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Matplotlib

# %% [markdown]
# Matplotlib is a plotting library. In this section give a brief introduction to the `matplotlib.pyplot` module, which provides a plotting system similar to that of MATLAB.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# By running this special iPython command, we will be displaying plots inline:

# %%
# %matplotlib inline

# %% [markdown]
# ###Plotting

# %% [markdown]
# The most important function in `matplotlib` is plot, which allows you to plot 2D data. Here is a simple example:

# %%
import numpy as np
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)
plt.figure()
plt.scatter(x, y)

# %% [markdown]
# With just a little bit of extra work we can easily plot multiple lines at once, and add a title, legend, and axis labels:

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin,color = "black")
plt.plot(x, y_cos,"red")
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

# %% [markdown]
# ###Subplots

# %% [markdown]
# You can plot different things in the same figure using the subplot function. Here is an example:

# %%
# Compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, color="red", alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(12)
# Create data
N = 60
g1 = np.array([0.6 + 0.6 *np.random.rand(N),np.random.rand(N)])
g2 = np.array([0.4 + 0.3 *np.random.rand(N),0.5*np.random.rand(N)])
g3 = np.array([0.3 *np.random.rand(N),0.3*np.random.rand(N)])



data = (g1, g2, g3)


colors = ("red", "green", "blue")
groups = ("one", "two", "three")

# Create plot
fig = plt.figure()
#ax = fig.add_subplot(1, 1, 1, axisbg="1.0")

for data, color, group in zip(data, colors, groups):
  x, y = data
  
  plt.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
plt.show()

# %%
#Write a python program where implement a sigmoid function(1/(1+e^-ax)) and take multiple plot varying the parameter a

# %% [markdown]
# Histogram plot

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

np.random.seed(42)
x = np.random.normal(size=1000)

plt.hist(x, density=True, bins=30)  # density=False would make counts
plt.ylabel('Probability')
plt.xlabel('Data');

# %%
import numpy as np
x = np.random.random_sample((10,10))
print("Original array: ")
print(x)
print("Values bigger than 10 =", x[x>0.92])
b = np.nonzero(x > 0.92)
print(np.shape(x[b[0],b[1]]))
# Out:
# Original array:
# [[0.02713115 0.2549245  0.24629463 0.87684642 0.47380388 0.61118598
#   0.33762685 0.44367812 0.36404702 0.11331731]
#  [0.26438772 0.60980403 0.11461467 0.99894749 0.81940983 0.13501511
#   0.9849219  0.20322926 0.8095047  0.87310362]
#  [0.31045401 0.00305937 0.80682011 0.85991927 0.83718061 0.74797102
#   0.16505207 0.53542886 0.54176711 0.84767341]
#  [0.22218098 0.55914779 0.02662133 0.4519555  0.16765932 0.57583495
#   0.1316887  0.27150525 0.60672274 0.73340065]
#  [0.98619962 0.26035076 0.99897254 0.64953441 0.66882974 0.12525287
#   0.14328436 0.40620596 0.84023694 0.59093165]
#  [0.12491427 0.77314837 0.28963144 0.06330076 0.40744176 0.19273863
#   0.01961364 0.63076878 0.46581393 0.45793376]
#  [0.57745943 0.2045302  0.32429693 0.26992401 0.7031265  0.91042359
#   0.8480797  0.62940496 0.28080245 0.42042053]
#  [0.85132265 0.97061845 0.33101061 0.85366179 0.50148883 0.59557163
#   0.19993511 0.19025299 0.31318792 0.32326638]
# ...

# %%
import numpy as np
a = np.array(["Mario","Maria"])
print(a[0:2][-1])
# Out:
# Maria
